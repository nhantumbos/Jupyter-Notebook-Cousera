# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samuel Orlando Nhantumbo**

# %% [markdown]
# Data Scientist

# %% [markdown]
# *I am interested in data science because off the power that the data give people, organizations and states to make well informed decisions about almost all problems that they are confroted with.*
#
# *The second its my love from data and my curiosty to explore and have fun doing it.*

# %% [markdown]
# ### Calculate result mathematical operations

# %%
2+4-4/8
# Out:
# 5.5

# %% [markdown]
# 1. Numbered
#  - Bullet
#  ***Horizontal line
#  ![gettyimages-668670696-612x612.jpg](attachment:gettyimages-668670696-612x612.jpg)
